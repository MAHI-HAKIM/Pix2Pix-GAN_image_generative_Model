# %% [markdown]
# **YAPAY ZEKA PROJE ÖDEVİ**
#
#
# ---
# **PIX2PIX GAN** algoritmasını kullanarak bir resimden haritaya dönüştürme modelini oluşturmak
#
# **Grup üyeleri**
# - **ADI SOYADI - GRUP NUMARASI**
# - Mahi A/Hakim Mohammed - B201210605
#
#
# **İÇERİK**
#
#
# 1.   GAN nedir
# 2.   Conditional GAN nedir
# 3.   PIX2PIX GAN nedir
# 4.   Örnek uygulama ve anlatımı
#
#
# ---

# %% [markdown]
# **GAN nedir**
#
#
#
# ---
#
#
# > Generative Adversarial Networks (GAN) fikri 2014 yılında Ian Goodfellow’un bir partide arkadaşlarıyla yaptığı bir sohbet sırasında ortaya çıkmış ve hemen ardından makale olarak yayınlanmıştır
#
# > Yayınlanmasından sonra hızla popülerleşen bu makale 5 yılda 15000'den fazla atıf almış, bu alanda önemli konferanslarda yayınlanan makale sayısı ise yılda 500'ün üzerine çıkmıştır.
#
# > GAN modeline üretmek istediğiniz veriden yeterli sayıda örnek verirseniz yine aynı veri tipinde yeni örnekler ürettirebilirsiniz.
#
# > Sisteme binlerce kuş fotoğrafı verirseniz sistem, bir kuşun nasıl görünmesi gerektiğini öğrenecek ve yeni kuş fotoğrafları üretecektir.
#
# ![Ekran görüntüsü 2024-05-11 184119.png](data:image/png;base64,...)
#
#
# > GAN’lerde birbiriyle çekişme halinde bulunan 2 farklı yapay sinir ağı bulunmaktadır. Bunlar Üretici (Generator) ve Ayırt Edici (Discriminator) ağ olarak adlandırılır. Üretici ağ, gerçeğe benzeyen yeni veriler (resimler, sesler, modeller vb.) üretirken Ayırt Edici ağ da sahte ve gerçek verileri birbirinden ayırt etmeye çalışır. Bu iki sinir ağı birbiriyle çekişirken Ayırt Edici ağ giderek gerçek ve sahte resimleri daha iyi ayırt etmeye başlar. Üretici ağ ise daha gerçekçi sahte resimler üretir. Bu düzeni kalpazan ve polis ikilisine benzetebiliriz. Zaman ilerledikçe polis, kalpazanları bulabilmek için sahte paraları yakalamada daha başarılı olur. Kalpazan ise polisi yenebilmek için daha gerçekçi sahte paralar üretmeye başlar.
#
# Biz kendi projemizde Generative Adversarial Network'un bir variantı olan Conditional GAN'ın bir varyasyonu olan PIX2PIX GAN algoritmasını inceleyerek örneğimizi yaptık.
#
#
#
# ---

# %% [markdown]
# **Conditional GAN nedir**
#
#
# ---
#
# > Koşullu GAN’lar (CGAN’lar), GAN modelinin bir uzantısıdır. CGAN’ların belirli koşullara veya niteliklere sahip sentetik verilerin oluşturmasına izin verilir.
#
# > Bir GAN modeli uzantısı olan CGAN iki bileşene sahiptir:
# - **Generator**: Girdi olarak gürültü vektörü ve etiket değeri alan, çıktı olarak da sahte bir veri örneği oluşturan yapay sinir ağıdır.
# -  **Discriminator**: Girdi olarak gerçek ve sahte veri örnekleri ve bu veri örneklerinin etiketlerini alan, gerçek veya sahte olmak üzere olasılıksal sonuç üreten yapay sinir ağıdır.
#
# > Koşullu Ganların en önemli özelliği Generator ve Discriminatorün bazı ek koşullandırma girdileri almalarıdır.
#
# > Örneğin, yeni tabular datalar oluşturmak için bir DCGAN’ı eğitirsek, Oluşturucu tarafından hangi belirli verilerin üretileceği üzerinde hiçbir kontrol yoktur. Üreticiden belirli bir verinin nasıl talep edileceğine dair bir mekanizma yoktur. Bu sorun, Koşullu GAN (CGAN) adı verilen bir GAN varyasyonu ile çözülebilir.
#
# > Bunu şu şekilde örnekleyebiliriz: Titanik veri seti için CGAN kullanarak sentetik veri üretmek istediğimizi varsayalım. Belirleyeceğimiz koşul için bir hedef değişken belirlemeliyiz. Yaşama durumu hedef değişkenimiz olsun (y değeri). Bu bilgiyi her ürettiğimiz veri için koşul olarak vereceğiz. Generator yaşama durumu = 0 olduğunu iddia ettiği bir kişinin verisini üretecektir. Discriminator bunun gerçek bir veri mi yoksa Generator tarafından üretilen sahte bir veri mi olduğuna dair bir değer üretecektir. Bu sayede her iki ağda ileri yayılım yapacaktır. Sonuç olarak bir loss değeri hesaplanacak ve geri yayılım ile ağlar kendilerini geliştireceklerdir.
#
# > Görüldüğü üzere CGAN’ı diğer GANlardan ayıran kısım her iki bileşeninin de (Generator ve Descriminator) girdi olarak bir koşul almasıdır. Aldığı bu hedef değişken sayesinde CGANlar denetimli bir yapay sinir ağı olmaktadır (standart GANlar denetimsizdir). Aşağıdaki şekilde bu durum daha iyi gözlemlenebilir.
#
# ![image.png](data:image/png;base64,...)
#
# CGAN'ları böylece tanımlayabiliriz. Şimdi de modelimizin üzerine kurulu olduğu ve temeli CGAN olan PIX2PIX alogirtmasını anlatıp örneğimize geçeceğiz.
#
# ---

# %% [markdown]
# **PIX2PIX GAN nedir**
#
#
# ---
#
# > Pix2Pix, genel
# amaçlı görüntüden görüntüye çeviri için
# tasarlanmış bir GAN modelidir.
#
# > Pix2Pix GAN görüntüden görüntüye dönüşüm yapabileceğiniz , deep convolutional neural network ile oluşturulmuş bir modeldir.
#
# > Pix2Pix modeli, çıktı görüntüsünün oluşturulmasının bir girişe ihtiyaç duyduğu ve bu durumda bir kaynak görüntüye bağlı olduğu bir tür koşullu GAN veya cGAN’dır.
#
# ![Ekran görüntüsü 2024-05-11 205810.png](data:image/png;base64,...)
#
#
# > Ayırıcıya hem kaynak görüntü hem de hedef görüntü sağlanır ve hedefin kaynak görüntünün makul bir dönüşümü olup olmadığını belirler.
#
# Burada PIX2PIX ile yapabileceğimiz bazı çalışmaların örnekleri
#
# ![Ekran görüntüsü 2024-05-11 210216.png](data:image/png;base64,...)
#
#
# > Biz Kendi örneğimizde Harita ve Mahalle dönüştürme işlemini Gerçekleştirdik.
#
# ---

# %% [markdown]
# **Örnek uygulamanın anlatımı**
#
#
#
# ---
#
# - Biz kendi projemizde PIX2PIX modelini kullanan bir örnek üzerinde çalışma yaptık.
# - örnekteki model, asıl olarak image to satelite olarak adlandırılmaktaydı.
# - modelin temel amacı, şehirlerdeki binaların çekildiği kuş bakışı resimlerini harita uygulamalarında binaların gösterildiği şekle dönüştüren bir model tasarlamaktır.
# - biz modeli 100 resimden oluşan bir dataset ile eğittik.
# - eğittikten sonra h5 uzantılı train edilmiş modelin dosyasını elde edebildik.
# - eğittiğimiz modeli farklı örnek resimlere uyguladık ve beklediğimiz sonuç ile elde ettiğimiz sonucu gözlemledik ve sonuçları aşağıdaki kod parçacıklarında paylaştık.
# - modelimizi 100 resimden oluşan farklı bir dataset ile eğittik ve çıktıların uyuştuklarını gözlemledik ve elde ettiğimiz sonuçları aşağıda paylaştık.
# - alt bloklarda üzerinde çalıştığımız modelin kod anlatımını yapacağız.

# %%
from google.colab import drive

# %% [markdown]
# - Eğiteceğimiz datasetleri drive üzerinden alacağımız için drive modulunu import ediyoruz.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - Bu satırı çalıştırarak kendi drive'ımızı content klasörünün içerisine eklşiyoruz.

# %%
from numpy import zeros
from numpy import ones
from numpy.random import randint
from keras.optimizers import Adam
from keras.initializers import RandomNormal
from keras.models import Model
from keras.layers import Input #changed
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Activation
from keras.layers import Concatenate
from keras.layers import Dropout
from keras.layers import BatchNormalization
from matplotlib import pyplot as plt
from tensorflow.keras.utils import plot_model #changed

# %% [markdown]
# - Burada gerekli olan kütühaneler eklenmiştir.

# %%
def define_encoder_block(layer_in, n_filters, batchnorm=True):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# add downsampling layer
	g = Conv2D(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# conditionally add batch normalization
	if batchnorm:
		g = BatchNormalization()(g, training=True)
	# leaky relu activation
	g = LeakyReLU(alpha=0.2)(g)
	return g



def define_discriminator(image_shape):

	# Ağırlık başlatma
	init = RandomNormal(stddev=0.02) #As described in the original paper

	# source image input
	in_src_image = Input(shape=image_shape)  #Image we want to convert to another image
	# target image input
	in_target_image = Input(shape=image_shape)  #Image we want to generate after training.

	# concatenate images, channel-wise
	merged = Concatenate()([in_src_image, in_target_image])

	# C64: 4x4 kernel Stride 2x2
	d = Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(merged)
	d = LeakyReLU(alpha=0.2)(d)
	# C128: 4x4 kernel Stride 2x2
	d = Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C256: 4x4 kernel Stride 2x2
	d = Conv2D(256, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C512: 4x4 kernel Stride 2x2
    # Not in the original paper. Comment this block if you want.
	d = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# second last output layer : 4x4 kernel but Stride 1x1
	d = Conv2D(512, (4,4), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# patch output
	d = Conv2D(1, (4,4), padding='same', kernel_initializer=init)(d)
	patch_out = Activation('sigmoid')(d)
	# define model
	model = Model([in_src_image, in_target_image], patch_out)
	# compile model
    #The model is trained with a batch size of one image and Adam opt.
    #with a small learning rate and 0.5 beta.
    #The loss for the discriminator is weighted by 50% for each model update.

	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, loss_weights=[0.5])
	return model

# %% [markdown]
# - Burada kodlayıcı  bloğun fonksiyon tanımı yapılmıştır.

# %%
# define a decoder block to be used in generator
def decoder_block(layer_in, skip_in, n_filters, dropout=True):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# add upsampling layer
	g = Conv2DTranspose(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# add batch normalization
	g = BatchNormalization()(g, training=True)
	# conditionally add dropout
	if dropout:
		g = Dropout(0.5)(g, training=True)
	# merge with skip connection
	g = Concatenate()([g, skip_in])
	# relu activation
	g = Activation('relu')(g)
	return g

# %% [markdown]
# - Burada kod çözücünün fonksiyon bloğu tanımı yapılmıştır.

# %%
# Üreteç Modelinin Tanımlanması - U-Net
# Bu fonksiyon, bağımsız üreteç modelini (U-Net) tanımlar.
def define_generator(image_shape=(256,256,3)):
	"""
    Üreteç modelini (U-Net) tanımlar.

    Args:
        image_shape: Giriş resim boyutu ve kanal sayısı. Varsayılan değer (256,256,3).

    Returns:
        Üreteç modeli.
    """
	# Ağırlık başlatma
	init = RandomNormal(stddev=0.02)
	# Giriş resmi
	in_image = Input(shape=image_shape)
	# Kodlayıcı modeli: C64-C128-C256-C512-C512-C512-C512-C512
	e1 = define_encoder_block(in_image, 64, batchnorm=False)
	e2 = define_encoder_block(e1, 128)
	e3 = define_encoder_block(e2, 256)
	e4 = define_encoder_block(e3, 512)
	e5 = define_encoder_block(e4, 512)
	e6 = define_encoder_block(e5, 512)
	e7 = define_encoder_block(e6, 512)
	# bottleneck, no batch norm and relu
	b = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(e7)
	b = Activation('relu')(b)
	# decoder model: CD512-CD512-CD512-C512-C256-C128-C64
	d1 = decoder_block(b, e7, 512)
	d2 = decoder_block(d1, e6, 512)
	d3 = decoder_block(d2, e5, 512)
	d4 = decoder_block(d3, e4, 512, dropout=False)
	d5 = decoder_block(d4, e3, 256, dropout=False)
	d6 = decoder_block(d5, e2, 128, dropout=False)
	d7 = decoder_block(d6, e1, 64, dropout=False)
	# output
	g = Conv2DTranspose(image_shape[2], (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d7) #Modified
	out_image = Activation('tanh')(g)  #Oluşturulan resimleri -1 ile 1 aralığında çıkarır. Girişlerin de -1 ile 1 aralığında olduğuna dikkat edin
	# modeli tanımlama
	model = Model(in_image, out_image)
	return model

# gen_model = define_generator((256,256,3))
# plot_model(gen_model, to_file='gen_model.png', show_shapes=True)


# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model, image_shape):
	# make weights in the discriminator not trainable
	for layer in d_model.layers:
		if not isinstance(layer, BatchNormalization):
			layer.trainable = False       #Descriminator layers set to untrainable in the combined GAN but
                                                #standalone descriminator will be trainable.

	# define the source image
	in_src = Input(shape=image_shape)
	# suppy the image as input to the generator
	gen_out = g_model(in_src)
	# supply the input image and generated image as inputs to the discriminator
	dis_out = d_model([in_src, gen_out])
	# src image as input, generated image and disc. output as outputs
	model = Model(in_src, [dis_out, gen_out])
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)

    #Total loss is the weighted sum of adversarial loss (BCE) and L1 loss (MAE)
    #Authors suggested weighting BCE vs L1 as 1:100.
	model.compile(loss=['binary_crossentropy', 'mae'],
               optimizer=opt, loss_weights=[1,100])
	return model

# select a batch of random samples, returns images and target
def generate_real_samples(dataset, n_samples, patch_shape):
	# unpack dataset
	trainA, trainB = dataset
	# choose random instances
	ix = randint(0, trainA.shape[0], n_samples)
	# retrieve selected images
	X1, X2 = trainA[ix], trainB[ix]
	# generate 'real' class labels (1)
	y = ones((n_samples, patch_shape, patch_shape, 1))
	return [X1, X2], y

# generate a batch of images, returns images and targets
def generate_fake_samples(g_model, samples, patch_shape):
	# generate fake instance
	X = g_model.predict(samples)
	# create 'fake' class labels (0)
	y = zeros((len(X), patch_shape, patch_shape, 1))
	return X, y

# %% [markdown]
# - Burada üreteç (Generator) fonksiyonun blok tanımını yaptık.
# - üreteç gerçek olmayan kopyaları üretmekten sorumluydu ve bu resimleri kullanarak Discriminatörü fake etmeye çalışıyordu.

# %%
# generate samples and save as a plot and save the model
#GAN models do not converge, we just want to find a good balance between
#the generator and the discriminator. Therefore, it makes sense to periodically
#save the generator model and check how good the generated image looks.

# oluşturacağımız modelin saklanacağı dosya
# model dosyasının bulunduğundan emin olunuz.
save_path = '/content/drive/MyDrive/data/maps/model/'


def summarize_performance(step, g_model, dataset, n_samples=3):
	# select a sample of input images
	[X_realA, X_realB], _ = generate_real_samples(dataset, n_samples, 1)
	# generate a batch of fake samples
	X_fakeB, _ = generate_fake_samples(g_model, X_realA, 1)
	# scale all pixels from [-1,1] to [0,1]
	X_realA = (X_realA + 1) / 2.0
	X_realB = (X_realB + 1) / 2.0
	X_fakeB = (X_fakeB + 1) / 2.0
	# plot real source images
	for i in range(n_samples):
		plt.subplot(3, n_samples, 1 + i)
		plt.axis('off')
		plt.imshow(X_realA[i])
	# plot generated target image
	for i in range(n_samples):
		plt.subplot(3, n_samples, 1 + n_samples + i)
		plt.axis('off')
		plt.imshow(X_fakeB[i])
	# plot real target image
	for i in range(n_samples):
		plt.subplot(3, n_samples, 1 + n_samples*2 + i)
		plt.axis('off')
		plt.imshow(X_realB[i])
	# save plot to file
	filename1 = '/content/drive/MyDrive/data/maps/model/plot_%06d.png' % (step+1)
	plt.savefig(filename1)
	plt.close()
	# save the generator model
	filename2 = '/content/drive/MyDrive/data/maps/model/model_%06d.h5' % (step+1)
	g_model.save(filename2)
	print('>Saved: %s and %s' % (filename1, filename2))

# train pix2pix models
def train(d_model, g_model, gan_model, dataset, n_epochs=100, n_batch=1):
	# determine the output square shape of the discriminator
	n_patch = d_model.output_shape[1]
	# unpack dataset
	trainA, trainB = dataset
	# calculate the number of batches per training epoch
	bat_per_epo = int(len(trainA) / n_batch)
	# calculate the number of training iterations
	n_steps = bat_per_epo * n_epochs
	# manually enumerate epochs
	for i in range(n_steps):
		# select a batch of real samples
		[X_realA, X_realB], y_real = generate_real_samples(dataset, n_batch, n_patch)
		# generate a batch of fake samples
		X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)
		# update discriminator for real samples
		d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
		# update discriminator for generated samples
		d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
		# update the generator
		g_loss, _, _ = gan_model.train_on_batch(X_realA, [y_real, X_realB])
		# summarize performance
		print('>%d, d1[%.3f] d2[%.3f] g[%.3f]' % (i+1, d_loss1, d_loss2, g_loss))
		# summarize model performance
		if (i+1) % (bat_per_epo * 10) == 0:
			summarize_performance(i, g_model, dataset)

# %% [markdown]
# - Bu kod bloğunda eğitme fonksiyonumuzu tanımladık ve oluşturacağımız h5 uzantılı model dosyalarının nereye saklanacağını belirttik.
# - biz veri setimizi drive üzerine yükleyip kullanıyoruz.
# eğitmek istediğiniz datasetin uyumlu bir şekilde çalışması için klaör hiyerarşisine dikkat ediniz.
# - **content**
#   - **drive**
#     - **MyDrive**
#       - **data**
#         - **maps**
#           - **train** // eğitilecek resimlerin bulunduğu klasör
#           - **model** // h5 uzantılı modelin saklanacağı klasör
#           - **test** // test resimlerin bulunduğu klasör
#         - **cityscapes**
#           - // maps veri setine benzer

# %%
# generate samples and save as a plot and save the model
#GAN models do not converge, we just want to find a good balance between
#the generator and the discriminator. Therefore, it makes sense to periodically
#save the generator model and check how good the generated image looks.

save_path = '/content/drive/MyDrive/data/cityscapes/model/'

def summarize_performance(step, g_model, dataset, n_samples=3):
	# select a sample of input images
	[X_realA, X_realB], _ = generate_real_samples(dataset, n_samples, 1)
	# generate a batch of fake samples
	X_fakeB, _ = generate_fake_samples(g_model, X_realA, 1)
	# scale all pixels from [-1,1] to [0,1]
	X_realA = (X_realA + 1) / 2.0
	X_realB = (X_realB + 1) / 2.0
	X_fakeB = (X_fakeB + 1) / 2.0
	# plot real source images
	for i in range(n_samples):
		plt.subplot(3, n_samples, 1 + i)
		plt.axis('off')
		plt.imshow(X_realA[i])
	# plot generated target image
	for i in range(n_samples):
		plt.subplot(3, n_samples, 1 + n_samples + i)
		plt.axis('off')
		plt.imshow(X_fakeB[i])
	# plot real target image
	for i in range(n_samples):
		plt.subplot(3, n_samples, 1 + n_samples*2 + i)
		plt.axis('off')
		plt.imshow(X_realB[i])
	# save plot to file
	filename1 = '/content/drive/MyDrive/data/cityscapes/model/plot_%06d.png' % (step+1)
	plt.savefig(filename1)
	plt.close()
	# save the generator model
	filename2 = '/content/drive/MyDrive/data/cityscapes/model/model_%06d.h5' % (step+1)
	g_model.save(filename2)
	print('>Saved: %s and %s' % (filename1, filename2))

# train pix2pix models
def train(d_model, g_model, gan_model, dataset, n_epochs=100, n_batch=1):
	# determine the output square shape of the discriminator
	n_patch = d_model.output_shape[1]
	# unpack dataset
	trainA, trainB = dataset
	# calculate the number of batches per training epoch
	bat_per_epo = int(len(trainA) / n_batch)
	# calculate the number of training iterations
	n_steps = bat_per_epo * n_epochs
	# manually enumerate epochs
	for i in range(n_steps):
		# select a batch of real samples
		[X_realA, X_realB], y_real = generate_real_samples(dataset, n_batch, n_patch)
		# generate a batch of fake samples
		X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)
		# update discriminator for real samples
		d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
		# update discriminator for generated samples
		d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
		# update the generator
		g_loss, _, _ = gan_model.train_on_batch(X_realA, [y_real, X_realB])
		# summarize performance
		print('>%d, d1[%.3f] d2[%.3f] g[%.3f]' % (i+1, d_loss1, d_loss2, g_loss))
		# summarize model performance
		if (i+1) % (bat_per_epo * 10) == 0:
			summarize_performance(i, g_model, dataset)

# %% [markdown]
# - Yukarıda tanımlamasını yaptığımız aynı kod ama farklı dataset kullanarak

# %%
from os import listdir
from numpy import asarray, load
from numpy import vstack
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from numpy import savez_compressed
from matplotlib import pyplot
import numpy as np

# %% [markdown]
# - Gerekli kütüphaneler kullanılmaktadır.

# %%
# load all images in a directory into memory
def load_images(path, size=(256,512)):
	"""
    Bir dizindeki tüm görüntüleri belleğe yükler.

    Args:
        path: Görüntülerin bulunduğu dizin.
        size: Yükleme boyutu. Varsayılan değer (256,512).

    Returns:
        List: Kaynak ve hedef görüntülerin listesi.
    """
	src_list, tar_list = list(), list()
	# enumerate filenames in directory, assume all are images
	for filename in listdir(path):
		# load and resize the image
		pixels = load_img(path + filename, target_size=size)
		# convert to numpy array
		pixels = img_to_array(pixels)
		# split into satellite and map
		sat_img, map_img = pixels[:, :256], pixels[:, 256:]
		src_list.append(sat_img)
		tar_list.append(map_img)
	return [asarray(src_list), asarray(tar_list)]

# %% [markdown]
# - Bu fonksiyonun amacı train edilecek resimleri belleğe saklamak.

# %%
path = '/content/drive/MyDrive/data/cityscapes/test/'

# %%
path = '/content/drive/MyDrive/data/cityscapes/train/'

# %%
path = '/content/drive/MyDrive/data/maps/train/'

# %%
path = '/content/drive/MyDrive/data/maps/test/'

# %% [markdown]
# - yukarıdaki dört satır 2 farklı dataset üzerine yapacağımız test ve eğitim işlemlerin ayrıştırmamıza yardımcı olur.
# - herhangi biri seçilmesi durumunda resimlerin yolu bu olur ve resimler bu yoldan alınır.

# %%
# dataset path

# load dataset
[src_images, tar_images] = load_images(path)
print('Loaded: ', src_images.shape, tar_images.shape)


n_samples = 3
for i in range(n_samples):
	pyplot.subplot(2, n_samples, 1 + i)
	pyplot.axis('off')
	pyplot.imshow(src_images[i].astype('uint8'))
# plot target image
for i in range(n_samples):
	pyplot.subplot(2, n_samples, 1 + n_samples + i)
	pyplot.axis('off')
	pyplot.imshow(tar_images[i].astype('uint8'))
pyplot.show()

#######################################

# from pix2pix_model import define_discriminator, define_generator, define_gan, train
# define input shape based on the loaded dataset
image_shape = src_images.shape[1:]
# define the models
d_model = define_discriminator(image_shape)
g_model = define_generator(image_shape)
# define the composite model
gan_model = define_gan(g_model, d_model, image_shape)

#Define data
# load and prepare training images
data = [src_images, tar_images]
# Out:
# Loaded:  (22, 256, 256, 3) (22, 256, 256, 3)
# /usr/local/lib/python3.10/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %% [markdown]
# - Burada dataset yükleme işlemi gerçekleştirilmektedir.

# %%
def preprocess_data(data):
	# load compressed arrays
	# unpack arrays
	X1, X2 = data[0], data[1]
	# scale from [0,255] to [-1,1]
	X1 = (X1 - 127.5) / 127.5
	X2 = (X2 - 127.5) / 127.5
	return [X1, X2]

# %%
dataset = preprocess_data(data)


from datetime import datetime
start1 = datetime.now()

train(d_model, g_model, gan_model, dataset, n_epochs=99, n_batch=1)
#Reports parameters for each batch (total 1096) for each epoch.
#For 10 epochs we should see 10960

stop1 = datetime.now()
#Execution time of the model
execution_time = stop1-start1
print("Execution time is: ", execution_time)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# >1, d1[0.406] d2[0.209] g[6.194]
# 1/1 [==============================] - 0s 36ms/step
# >2, d1[0.167] d2[0.135] g[6.576]
# 1/1 [==============================] - 0s 23ms/step
# >3, d1[0.055] d2[0.280] g[5.674]
# 1/1 [==============================] - 0s 30ms/step
# >4, d1[0.067] d2[0.151] g[5.227]
# 1/1 [==============================] - 0s 31ms/step
# >5, d1[0.179] d2[0.430] g[5.868]
# 1/1 [==============================] - 0s 26ms/step
# >6, d1[0.218] d2[0.090] g[6.658]
# 1/1 [==============================] - 0s 21ms/step
# >7, d1[0.073] d2[0.474] g[6.651]
# 1/1 [==============================] - 0s 21ms/step
# >8, d1[0.156] d2[0.090] g[4.685]
# 1/1 [==============================] - 0s 32ms/step
# >9, d1[0.183] d2[0.091] g[5.257]
# 1/1 [==============================] - 0s 26ms/step
# >10, d1[0.086] d2[0.323] g[6.004]
# 1/1 [==============================] - 0s 24ms/step
# >11, d1[0.132] d2[0.174] g[6.703]
# ...

# %% [markdown]
# - Bu aşamada eğitim işlemi başlatılır.
# - yapmış olduğumuz eğitim işlemi toplam 35 dk sürmüştür.
# - train işlemi 2 defa yapılmıştır çünkü 2 farklı dataset kullanılmıştır yalnız  sadece bir sonuç gözükmektedir çünkü aynı fonksiyon üzerinde eğitim yaptık.

# %%
from keras.models import load_model
from numpy.random import randint
model = load_model('/content/drive/MyDrive/data/maps/model/model_001980.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# - Bu aşamada eğitilmiş model hazır hale gelmiş olur ve yükleme işlemine tabi tutulur.
# - görüldüğü üzere 2 kez calıştırlımış bir komuttur bu çünkü 2 farklı dataset ile eğitilmiş modelleri kullanıyoruz.

# %%
from keras.models import load_model
from numpy.random import randint
model = load_model('/content/drive/MyDrive/data/cityscapes/model/model_008190.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
def plot_images(src_img, gen_img, tar_img):
	images = vstack((src_img, gen_img, tar_img))
	# scale from [-1,1] to [0,1]
	images = (images + 1) / 2.0
	titles = ['Source', 'Generated', 'Expected']
	# plot images row by row
	for i in range(len(images)):
		# define subplot
		pyplot.subplot(1, 3, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(images[i])
		# show title
		pyplot.title(titles[i])
	pyplot.show()

# %%
dataset = preprocess_data(data)

# %%
[X1, X2] = dataset
# select random example
ix = randint(0, len(X1), 1)
src_image, tar_image = X1[ix], X2[ix]
# generate image from source
gen_image = model.predict(src_image)
# plot all three images
plot_images(src_image, gen_image, tar_image)
# Out:
# 1/1 [==============================] - 0s 462ms/step

# %% [markdown]
# - Burada görüldüğü gibi 1.dataset ile eğittiğimiz modelin oluşturduğu bir resimdir.
# - eğitimde 100 tane resim kullandık ve yukarıda gösterilen resim eğitimde kullanılan bir resim değildir sadece örnek bir resimdir.
# - üretilmiş resim tahmin edilmiş resime çok benzemektedir.

# %%
[X1, X2] = dataset
# select random example
ix = randint(0, len(X1), 1)
src_image, tar_image = X1[ix], X2[ix]
# generate image from source
gen_image = model.predict(src_image)
# plot all three images
plot_images(src_image, gen_image, tar_image)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %% [markdown]
# - Burada herhangi bir sokağın resmini soyutlanmış bir resime dönüştürme yapılmıştır.
# - Bu bizim aynı model üzerinde uyguladığımız 2.dataset'in bir örneğidir yani eğitmiş resimlerden değildir.
# - görüldüğü gibi üretilmiş resim tahmin edilmiş resime çok benzer ve bu yaptığımız eğitimin kısmen başarılı olduğunu gösterir.
#
# ---

# %% [markdown]
# **SONLANDIRMA**
#
#
# ---
#
# - Bu uygulama yapay sinir ağlarını, GAN algoritmalarını ve onun varyasyonlarını anlamamıza çok yardımcı oldu.
# - Hocaların gösterdiği ilgi için teşekkür ederiz.
#
# **KAYNAKÇA**
# - https://medium.com/devcist/pix2pix-gan-for-image-to-image-translation-7f650345fa3f
# - https://www.kdnuggets.com/2017/01/generative-adversarial-networks-hot-topic-machine-learning.html
# - https://cihanongun.medium.com/generative-adversarial-networks-gan-alan%C4%B1nda-okunmas%C4%B1-gereken-10-makale-ee9c9ecee3d
# - https://aws.amazon.com/tr/what-is/gan/
# - https://www.kaggle.com/datasets/vikramtiwari/pix2pix-dataset?resource=download
# - https://www.youtube.com/watch?v=6pUSZgPJ3Yg&t=1140s
